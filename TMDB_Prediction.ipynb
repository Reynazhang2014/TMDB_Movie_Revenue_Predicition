# %%
import ujson
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import chi2
from pandas.io.json import json_normalize
from sklearn import linear_model
import json
import ast

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
def process_dict(x): 
    try:
        return len(ast.literal_eval(x))
    except:
        return 0

# %%
train['cast_ct'] = train.cast.apply(process_dict)

# %%
train_num = train.select_dtypes(['int','float']).fillna(0)

X = train_num.drop(columns = ['revenue'])
y = train_num['revenue']
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state = 42, test_size = 0.2)

# %%
lin_model = linear_model.LinearRegression()
lin_model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
test['revenue'] = lin_model.predict(test[X.columns].fillna(0))

# %%
test[['id','revenue']].to_csv('test_submission.csv',index = False, header = True)

# %%
# Out:
#         id     budget  popularity  runtime
# 0        1   14000000    6.575393     93.0
# 1        2   40000000    8.248895    113.0
# 2        3    3300000   64.299990    105.0
# 3        4    1200000    3.174936    122.0
# 4        5          0    1.148070    118.0
# 5        6    8000000    0.743274     83.0
# 6        7   14000000    7.286477     92.0
# 7        8          0    1.949044     84.0
# 8        9          0    6.902423    100.0
# 9       10    6000000    4.672036     91.0
# 10      11    1000000   14.774066    119.0
# 11      12          0   10.543750     98.0
# 12      13   15000000   20.726578    122.0
# 13      14   53000000   13.314233    118.0
# 14      15  102000000   20.666063    145.0
# 15      16     500000    1.018477     97.0
# 16      17   26000000    6.336927     85.0
# 17      18          0    4.183558    111.0
# 18      19    8000000    6.496259     96.0
# 19      20   32000000   11.359659     87.0
# 20      21   80000000   12.000579    130.0
# 21      22    4000000    7.992290     95.0
# 22      23          0    7.820787    116.0
# 23      24          0    1.323333     92.0
# 24      25          0    7.434577     87.0
# 25      26          0    1.252367     95.0
# 26      27   10000000    4.305735    110.0
# 27      28   11000000   10.841891     93.0
# 28      29    6000000    6.759181     84.0
# 29      30   45000000    7.818620     89.0
# ...    ...        ...         ...      ...
# 2970  2971   25000000    9.805017    129.0
# 2971  2972   20000000    4.414928    110.0
# 2972  2973          0    4.154861     94.0
# 2973  2974          0    3.868014     94.0
# 2974  2975   20000000    5.871243     96.0
# 2975  2976   45000000   11.618472     86.0
# 2976  2977   16000000    4.372616     96.0
# 2977  2978   53000000    5.396200    102.0
# 2978  2979          0   16.529300    119.0
# 2979  2980   35000000    6.629999    106.0
# 2980  2981     300000    0.350207    144.0
# 2981  2982          0    3.069108     97.0
# 2982  2983     500000    4.893812     85.0
# 2983  2984   35000000    5.660835    108.0
# 2984  2985   80000000   13.334952    117.0
# 2985  2986   37665000    5.388535    113.0
# 2986  2987   20000000   12.553403     84.0
# 2987  2988          0    1.292125     90.0
# 2988  2989          0    0.984515     94.0
# 2989  2990          0    0.851599     75.0
# 2990  2991          0    1.560980     90.0
# 2991  2992   13000000    4.794088    112.0
# 2992  2993    1135654    3.878515    149.0
# 2993  2994   60000000   14.092373    128.0
# 2994  2995          0    7.438381    106.0
# 2995  2996          0    9.853270    102.0
# 2996  2997          0    3.727996    102.0
# 2997  2998   65000000   14.482345    120.0
# 2998  2999   42000000   15.725542     90.0
# 2999  3000   35000000   10.512109    106.0
#
# [3000 rows x 4 columns]
